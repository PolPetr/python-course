# %% [markdown]
# <a href="https://colab.research.google.com/github/PolPetr/python-course/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22data_analysis_HW%2005.12_Petrova_P_S_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1: выгрузка файлов

# %% [markdown]
# 1. Зайдите в репозиторий датасетов для обучения диалоговых систем
# 2. Найдите все файлы с расширением *.txt (их всего 5 в репозитории)
# 3. Выгрузите каждый файл с помощью утилиты `wget`
# - Для этого откройте датасет в браузере, например, https://github.com/Phylliida/Dialogue-Datasets/blob/master/TwitterLowerAsciiCorpus.txt
# - Затем найдите кнопку `raw`, которая откроет вам файл "как есть" (как в блокноте!)
# - Скопируйте ссылку на файл (она выглядит так: https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt)
# - Воспользуйтесь `wget`
# ---
# Как использовать `wget`:
# ---

# %%
# @title
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt -O twitter.txt
# Out:
# --2025-12-05 16:19:03--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 593707 (580K) [text/plain]
# Saving to: ‘twitter.txt’
#
# twitter.txt         100%[===================>] 579.79K  --.-KB/s    in 0.04s
#
# 2025-12-05 16:19:03 (15.2 MB/s) - ‘twitter.txt’ saved [593707/593707]

# %% [markdown]
# Здесь:
# - ! указывает на то, что это консольная утилита, а не код на python
# - после wget идет полный адрес ссылки для скачивания файла
# - после параметра `-O` указываем название файла, под которым мы хотим скачать файл

# %%
# @title
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterConvCorpus.txt -O concorpus.txt
# Out:
# --2025-12-05 16:25:49--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterConvCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 612338 (598K) [text/plain]
# Saving to: ‘concorpus.txt’
#
# concorpus.txt       100%[===================>] 597.99K  --.-KB/s    in 0.05s
#
# 2025-12-05 16:25:49 (11.8 MB/s) - ‘concorpus.txt’ saved [612338/612338]

# %%
# @title
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/MovieCorpus.txt -O moviecorpus.txt
# Out:
# --2025-12-05 16:26:02--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/MovieCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16976724 (16M) [text/plain]
# Saving to: ‘moviecorpus.txt’
#
# moviecorpus.txt     100%[===================>]  16.19M  --.-KB/s    in 0.1s
#
# 2025-12-05 16:26:02 (140 MB/s) - ‘moviecorpus.txt’ saved [16976724/16976724]

# %%
# @title
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCSplitWordsCorpus.txt -O wordscorpus.txt
# Out:
# --2025-12-05 16:26:18--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCSplitWordsCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173003 (18M) [text/plain]
# Saving to: ‘wordscorpus.txt’
#
# wordscorpus.txt     100%[===================>]  18.28M  --.-KB/s    in 0.1s
#
# 2025-12-05 16:26:18 (122 MB/s) - ‘wordscorpus.txt’ saved [19173003/19173003]

# %%
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCCorpus.txt -O bnccorpus.txt
# Out:
# --2025-12-05 16:26:36--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19081694 (18M) [text/plain]
# Saving to: ‘bnccorpus.txt’
#
# bnccorpus.txt       100%[===================>]  18.20M  --.-KB/s    in 0.1s
#
# 2025-12-05 16:26:36 (136 MB/s) - ‘bnccorpus.txt’ saved [19081694/19081694]

# %% [markdown]
# ## Задание 2: открываем файлы

# %% [markdown]
# Изучите туториал по работе с файлами, который вы получили в чате. Каждый файл нужно теперь открыть, а его содержание - записать в переменную *любым удобным вам способом*
#
# Пример:

# %%
# Открываем файл с указанием кодировки
file = open('twitter.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 593707 символов
# "what's up dadyo when did you get back on twitter? haha\nlike 2 weeks ago and it's going as terribly a"

# %%
# Открываем файл с указанием кодировки
file_1 = open('concorpus.txt', 'r', encoding='utf-8')
dataset_content_1 = file_1.read()
file_1.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content_1)} символов")
dataset_content_1[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 598556 символов
# "what's up dadyo when did you get back on Twitter? Haha\nlike 2 weeks ago and it's going as terribly a"

# %%
# Открываем файл с указанием кодировки
file_2 = open('moviecorpus.txt', 'r', encoding='utf-8')
dataset_content_2 = file_2.read()
file_2.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content_2)} символов")
dataset_content_2[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 16976724 символов
# "Colonel Durnford... William Vereker. I hear you 've been seeking Officers?\nGood ones, yes, Mr Vereke"

# %%
# Открываем файл с указанием кодировки
file_3 = open('wordscorpus.txt', 'r', encoding='utf-8')
dataset_content_3 = file_3.read()
file_3.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content_3)} символов")
dataset_content_3[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 19173003 символов
# 'You enjoyed yourself in America\nEh\ndid you\nOh I covered a nice trip yes\nOh very good\nsaw Mary and An'

# %%
# Открываем файл с указанием кодировки
file_4 = open('bnccorpus.txt', 'r', encoding='utf-8')
dataset_content_4 = file_4.read()
file_4.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content_4)} символов")
dataset_content_4[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 19081694 символов
# 'You enjoyed yourself in America\nEh\ndid you\nOh I covered a nice tripyes\nOh very good\nsaw Mary and And'

# %% [markdown]
# ## Задание 3: первичный анализ

# %% [markdown]
# Выведем статистику для каждого файла по образцу:

# %%
# 1. Разбиваем содержание файла на строки
file = open('twitter.txt', 'r', encoding='utf-8')
all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

for line in all_lines:
  total_lines += 1

  line_content = line.strip()
  line_length = len(line_content)
  total_chars += line_length

  if line_length > 0:
    non_empty_lines += 1

  words_in_line = line_content.split()
  total_words += len(words_in_line)

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

for line in all_lines:
    line_content = line.strip()
    line_length = len(line_content)

    if line_length > max_line_length:
      max_line_length = line_length
    if line_length < min_line_length:
      min_line_length = line_length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 16556
# Непустых строк: 10514
# Всего слов: 112977
# Всего символов: 575565
# Макс. длина строки: 146
# Мин. длина строки: 0

# %%
# 1. Разбиваем содержание файла на строки
file = open('concorpus.txt', 'r', encoding='utf-8')
all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

for line in all_lines:
  total_lines += 1

  line_content = line.strip()
  line_length = len(line_content)
  total_chars += line_length

  if line_length > 0:
    non_empty_lines += 1

  words_in_line = line_content.split()
  total_words += len(words_in_line)

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

for line in all_lines:
    line_content = line.strip()
    line_length = len(line_content)

    if line_length > max_line_length:
      max_line_length = line_length
    if line_length < min_line_length:
      min_line_length = line_length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 16556
# Непустых строк: 10628
# Всего слов: 114910
# Всего символов: 582000
# Макс. длина строки: 146
# Мин. длина строки: 0

# %%
# 1. Разбиваем содержание файла на строки
file = open('moviecorpus.txt', 'r', encoding='utf-8')
all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

for line in all_lines:
  total_lines += 1

  line_content = line.strip()
  line_length = len(line_content)
  total_chars += line_length

  if line_length > 0:
    non_empty_lines += 1

  words_in_line = line_content.split()
  total_words += len(words_in_line)

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

for line in all_lines:
    line_content = line.strip()
    line_length = len(line_content)

    if line_length > max_line_length:
      max_line_length = line_length
    if line_length < min_line_length:
      min_line_length = line_length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 304713
# Непустых строк: 304713
# Всего слов: 3185395
# Всего символов: 16664290
# Макс. длина строки: 3039
# Мин. длина строки: 0

# %%
# 1. Разбиваем содержание файла на строки
file = open('wordscorpus.txt', 'r', encoding='utf-8')
all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

for line in all_lines:
  total_lines += 1

  line_content = line.strip()
  line_length = len(line_content)
  total_chars += line_length

  if line_length > 0:
    non_empty_lines += 1

  words_in_line = line_content.split()
  total_words += len(words_in_line)

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

for line in all_lines:
    line_content = line.strip()
    line_length = len(line_content)

    if line_length > max_line_length:
      max_line_length = line_length
    if line_length < min_line_length:
      min_line_length = line_length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 611014
# Непустых строк: 606486
# Всего слов: 4052241
# Всего символов: 18561989
# Макс. длина строки: 2773
# Мин. длина строки: 0

# %%
# 1. Разбиваем содержание файла на строки
file = open('bnccorpus.txt', 'r', encoding='utf-8')
all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

for line in all_lines:
  total_lines += 1

  line_content = line.strip()
  line_length = len(line_content)
  total_chars += line_length

  if line_length > 0:
    non_empty_lines += 1

  words_in_line = line_content.split()
  total_words += len(words_in_line)

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

for line in all_lines:
    line_content = line.strip()
    line_length = len(line_content)

    if line_length > max_line_length:
      max_line_length = line_length
    if line_length < min_line_length:
      min_line_length = line_length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 611014
# Непустых строк: 606486
# Всего слов: 3719853
# Всего символов: 18348789
# Макс. длина строки: 2701
# Мин. длина строки: 0

# %% [markdown]
# ## Задание 4: чистка текста

# %%
import re

cleaned_lines = [] # чистим текст построчно (сохраняем каждую очищенную строку в список)
all_cleaned_words = [] # также сохраняем все слова после очистки в список

with open('twitter.txt', 'r', encoding='utf-8') as file:
  all_lines = file.readlines()
  for line in all_lines:
    line = line.strip()
    line = re.sub(r'[^\w\s]', '', line)
    line = re.sub(r'[\s+]', ' ', line)
    line = line.lower()
    if line:
      cleaned_lines.append(line)
      words = line.split()
      for word in words:
        if len(word) > 1:
          all_cleaned_words.append(word)

# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words)}")
# Out:
# Пример очищенной строки: whats up dadyo when did you get back on twitter haha...
# Всего очищенных слов: 104912

# %%
import re

cleaned_lines = [] # чистим текст построчно (сохраняем каждую очищенную строку в список)
all_cleaned_words = [] # также сохраняем все слова после очистки в список

with open('concorpus.txt', 'r', encoding='utf-8') as file:
  all_lines = file.readlines()
  for line in all_lines:
    line = line.strip()
    line = re.sub(r'[^\w\s]', '', line)
    line = re.sub(r'[\s+]', ' ', line)
    line = line.lower()
    if line:
      cleaned_lines.append(line)
      words = line.split()
      for word in words:
        if len(word) > 1:
          all_cleaned_words.append(word)

# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words)}")
# Out:
# Пример очищенной строки: whats up dadyo when did you get back on twitter haha...
# Всего очищенных слов: 104922

# %%
import re

cleaned_lines = [] # чистим текст построчно (сохраняем каждую очищенную строку в список)
all_cleaned_words = [] # также сохраняем все слова после очистки в список

with open('moviecorpus.txt', 'r', encoding='utf-8') as file:
  all_lines = file.readlines()
  for line in all_lines:
    line = line.strip()
    line = re.sub(r'[^\w\s]', '', line)
    line = re.sub(r'[\s+]', ' ', line)
    line = line.lower()
    if line:
      cleaned_lines.append(line)
      words = line.split()
      for word in words:
        if len(word) > 1:
          all_cleaned_words.append(word)

# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words)}")
# Out:
# Пример очищенной строки: colonel durnford william vereker i hear you ve been seeking officers...
# Всего очищенных слов: 3001929

# %%
import re

cleaned_lines = [] # чистим текст построчно (сохраняем каждую очищенную строку в список)
all_cleaned_words = [] # также сохраняем все слова после очистки в список

with open('wordscorpus.txt', 'r', encoding='utf-8') as file:
  all_lines = file.readlines()
  for line in all_lines:
    line = line.strip()
    line = re.sub(r'[^\w\s]', '', line)
    line = re.sub(r'[\s+]', ' ', line)
    line = line.lower()
    if line:
      cleaned_lines.append(line)
      words = line.split()
      for word in words:
        if len(word) > 1:
          all_cleaned_words.append(word)

# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words)}")
# Out:
# Пример очищенной строки: you enjoyed yourself in america...
# Всего очищенных слов: 3754297

# %%
import re

cleaned_lines = [] # чистим текст построчно (сохраняем каждую очищенную строку в список)
all_cleaned_words = [] # также сохраняем все слова после очистки в список

with open('bnccorpus.txt', 'r', encoding='utf-8') as file:
  all_lines = file.readlines()
  for line in all_lines:
    line = line.strip()
    line = re.sub(r'[^\w\s]', '', line)
    line = re.sub(r'[\s+]', ' ', line)
    line = line.lower()
    if line:
      cleaned_lines.append(line)
      words = line.split()
      for word in words:
        if len(word) > 1:
          all_cleaned_words.append(word)

# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words)}")
# Out:
# Пример очищенной строки: you enjoyed yourself in america...
# Всего очищенных слов: 3524835

# %% [markdown]
# ## Задание 5: статистика

# %% [markdown]
# Часть 1: получаем статистику распределений длин слов

# %% [markdown]
# *Как получить статистику по каждому из 5 документов, а не только по последнему? Каждый раз по-новому называть переменные?*

# %%
# Статистика по очищенным данным
total_words = len(all_cleaned_words)
total_chars = 0
word_lengths = []

# Ваш код здесь: создайте список длин слов word_lengths
#                и посчитайте общее количество символов total_chars
for word in all_cleaned_words:
  length = len(word)
  word_lengths.append(length)
# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count = {}
for length in word_lengths:
  if length in word_length_count:
# Ваш код здесь: для каждого значения длины в списке word_lengths
#                если длина уже зафиксирована в word_length_count, то выполняем >
        word_length_count[length] += 1
  else:
        word_length_count[length] = 1

# Ожидаемый результат:
print(f"Слов после очистки: {total_words}")
print(f"Символов после очистки: {total_chars}")
print("Распределение длин слов:")
for length in sorted(word_length_count.keys()):
    print(f"  {length} букв: {word_length_count[length]} слов")
# Out:
# Слов после очистки: 3524835
# Символов после очистки: 0
# Распределение длин слов:
#   2 букв: 666389 слов
#   3 букв: 880968 слов
#   4 букв: 880766 слов
#   5 букв: 425302 слов
#   6 букв: 255069 слов
#   7 букв: 175610 слов
#   8 букв: 102856 слов
#   9 букв: 60865 слов
#   10 букв: 34706 слов
#   11 букв: 16675 слов
#   12 букв: 10611 слов
#   13 букв: 5627 слов
#   14 букв: 3330 слов
#   15 букв: 1970 слов
#   16 букв: 1292 слов
#   17 букв: 667 слов
#   18 букв: 559 слов
#   19 букв: 331 слов
#   20 букв: 262 слов
#   21 букв: 173 слов
#   22 букв: 162 слов
#   23 букв: 94 слов
#   24 букв: 98 слов
#   25 букв: 62 слов
#   26 букв: 45 слов
#   27 букв: 56 слов
#   28 букв: 32 слов
#   29 букв: 28 слов
#   30 букв: 31 слов
#   31 букв: 12 слов
#   32 букв: 34 слов
#   33 букв: 16 слов
#   34 букв: 14 слов
#   35 букв: 18 слов
#   36 букв: 17 слов
#   37 букв: 2 слов
#   38 букв: 3 слов
#   39 букв: 18 слов
#   40 букв: 3 слов
#   41 букв: 2 слов
#   42 букв: 6 слов
#   43 букв: 2 слов
#   44 букв: 3 слов
#   45 букв: 7 слов
#   47 букв: 4 слов
#   48 букв: 4 слов
#   49 букв: 1 слов
#   51 букв: 2 слов
#   53 букв: 1 слов
#   54 букв: 1 слов
#   56 букв: 2 слов
#   57 букв: 1 слов
#   58 букв: 1 слов
#   59 букв: 5 слов
#   60 букв: 7 слов
#   63 букв: 1 слов
#   65 букв: 4 слов
#   66 букв: 1 слов
#   87 букв: 1 слов
#   90 букв: 1 слов
#   104 букв: 1 слов
#   105 букв: 2 слов
#   112 букв: 1 слов
#   114 букв: 1 слов

# %% [markdown]
# Часть 2: частотность слов

# %%
# Считаем частотность слов (по аналогии с подсчетом word_length_count)
word_frequency = {}
# Ваш код здесь:
for word in all_cleaned_words:
  if word in word_frequency:
        word_frequency[word] += 1
  else:
        word_frequency[word] = 1

# Находим топ-10 самых частых слов
# Начинаем с формирования кортежей вида (частотность слова, лексема)
word_count_pairs = []
for word, count in word_frequency.items():
    word_count_pairs.append((count, word))

# Сортируем вручную через вложенные циклы
for i in range(len(word_count_pairs)):
    for j in range(i + 1, len(word_count_pairs)):
        if word_count_pairs[j][0] > word_count_pairs[i][0]:
            # Меняем местами
            temp = word_count_pairs[i]
            word_count_pairs[i] = word_count_pairs[j]
            word_count_pairs[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs))):
    count, word = word_count_pairs[i]
    print(f"  {i+1}. '{word}': {count} раз")

# Анализ уникальных слов
unique_words = {}
for word in all_cleaned_words:
  unique_words[word] = 1

print(f"\nВсего уникальных слов: {len(unique_words)}")
